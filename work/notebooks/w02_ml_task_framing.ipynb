# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hamna0696/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("""
ML Task Type: Binary Classification

The task is to classify each content page into one of two classes:
1 = declining
0 = not declining.

The target is is_declining_label. It is derived from the observed
trend_direction of the page. The model should use other content and
performance features, while excluding trend_direction and trend_pct
because they directly define the label and would cause data leakage.
""")
# Out:
# ML Task Type: Binary Classification
#
# The task is to classify each content page into one of two classes:
# 1 = declining
# 0 = not declining.
#
# The target is is_declining_label. It is derived from the observed
# trend_direction of the page. The model should use other content and
# performance features, while excluding trend_direction and trend_pct
# because they directly define the label and would cause data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("""
Target: is_declining_label

The target is whether a content page is declining or not:
1 = declining
0 = not declining.

The label comes from trend_direction, where a page is labelled
declining when trend_direction is "down". This is a defined label
derived from observed traffic trends, so trend_direction and trend_pct
must not be used as model features because they would cause leakage.
""")
# Out:
# Target: is_declining_label
#
# The target is whether a content page is declining or not:
# 1 = declining
# 0 = not declining.
#
# The label comes from trend_direction, where a page is labelled
# declining when trend_direction is "down". This is a defined label
# derived from observed traffic trends, so trend_direction and trend_pct
# must not be used as model features because they would cause leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("""
Success Metric: Recall

We will use recall as the main success metric.

Recall measures how many of the actually declining content pages
the model correctly identifies. A higher recall means fewer
declining pages are missed.

Our goal is to identify as many genuinely declining pages as
possible so that editors can review them.
""")
# Out:
# Success Metric: Recall
#
# We will use recall as the main success metric.
#
# Recall measures how many of the actually declining content pages
# the model correctly identifies. A higher recall means fewer
# declining pages are missed.
#
# Our goal is to identify as many genuinely declining pages as
# possible so that editors can review them.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
print("""
Unit of Analysis: One Content Page

Each row in the dataframe represents one content item or page.
The content_id uniquely identifies the page, while client_id identifies
the pseudonymized client associated with it.

Therefore, the model makes one prediction for each content page.
""")
# Out:
# Unit of Analysis: One Content Page
#
# Each row in the dataframe represents one content item or page.
# The content_id uniquely identifies the page, while client_id identifies
# the pseudonymized client associated with it.
#
# Therefore, the model makes one prediction for each content page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("""
Why ML Instead of a Fixed Rule?

A fixed rule could use a single threshold to identify declining
content, but it would not consider the combination of many different
content, keyword, and performance features.

Machine learning can learn patterns from multiple features together
and help identify which content pages are more likely to be declining.

The model must exclude trend_direction and trend_pct because they are
used to define the target and would cause data leakage.
""")
# Out:
# Why ML Instead of a Fixed Rule?
#
# A fixed rule could use a single threshold to identify declining
# content, but it would not consider the combination of many different
# content, keyword, and performance features.
#
# Machine learning can learn patterns from multiple features together
# and help identify which content pages are more likely to be declining.
#
# The model must exclude trend_direction and trend_pct because they are
# used to define the target and would cause data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
